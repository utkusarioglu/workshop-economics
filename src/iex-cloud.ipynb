# %% [markdown]
# # IEX Cloud Workshop

# %%
import pandas as pd
from econ_utils import create_df, iex_cloud_api

# %% [markdown]
# ### Get the crypto list

# %%
crypto_list = iex_cloud_api("ref-data/crypto/symbols")
crypto_list_df = create_df(crypto_list)
crypto_list_df
# Out:
#       symbol                 name exchange        date    type region  \
# 0     BTCUSD       Bitcoin to USD     None  2022-04-12  crypto     US
# 1     ETHUSD      Ethereum to USD     None  2022-04-12  crypto     US
# 2     ETHBTC  Ethereum to Bitcoin     None  2022-04-12  crypto     US
# 3     ZECUSD         Zcash to USD     None  2022-04-12  crypto     US
# 4     ZECBTC     Zcash to Bitcoin     None  2022-04-12  crypto     US
# ...      ...                  ...      ...         ...     ...    ...
# 2009  BSWETH           BSW to ETH     None  2022-04-12  crypto     US
# 2010  FILTRY           FIL to TRY     None  2022-04-12  crypto     US
# 2011  FTMEUR           FTM to EUR     None  2022-04-12  crypto     US
# 2012  GMTGBP           GMT to GBP     None  2022-04-12  crypto     US
# 2013  ZILTRY           ZIL to TRY     None  2022-04-12  crypto     US
#
#      currency  isEnabled
# 0         USD       True
# 1         USD       True
# 2         BTC       True
# ...

# %% [markdown]
# ### Get SP 100 list

# %%
sp_100_df = pd.read_excel("../data/SP100.xlsx")
sp_100_df
# Out:
#     Symbol              Company Name                  Sector
# 0     AAPL                     Apple  Information Technology
# 1     ABBV                    AbbVie             Health Care
# 2      ABT                    Abbott             Health Care
# 3      ACN                 Accenture  Information Technology
# 4     ADBE                     Adobe  Information Technology
# ..     ...                       ...                     ...
# 96      VZ                   Verizon  Communication Services
# 97     WBA  Walgreens Boots Alliance        Consumer Staples
# 98     WFC               Wells Fargo              Financials
# 99     WMT                   Walmart        Consumer Staples
# 100    XOM                ExxonMobil                  Energy
#
# [101 rows x 3 columns]
